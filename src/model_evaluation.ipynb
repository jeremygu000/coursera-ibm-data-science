# %% [markdown]
# | Model | Relative Cost Y:N | True Positive Rate (Sensitivity) | Specificity (accuracy in N) | False Positive Rate (1 - Specificity) |
# |-------|-------------------|----------------------------------|-----------------------------|---------------------------------------|
# |   1   |       1:1         |             0.45                 |          0.97               |               0.03                    |
# |   2   |      1.5:1        |             0.60                 |          0.92               |               0.08                    |
# |   3   |       4:1         |             0.68                 |          0.85               |               0.15                    |
# |   4   |       9:1         |             0.97                 |          0.35               |               0.65                    |

# %% [markdown]
# ### 1. 取出所有模型下的 Sensitivity（TPR） 和 FPR
# | Model | TPR (Sensitivity) | FPR (1 - Specificity) |
# | ----- | ----------------- | --------------------- |
# | 1     | 0.45              | 0.03                  |
# | 2     | 0.60              | 0.08                  |
# | 3     | 0.68              | 0.15                  |
# | 4     | 0.97              | 0.65                  |

# %%
import matplotlib.pyplot as plt

# 直接用表格里的值
fpr = [0.03, 0.08, 0.15, 0.65]
tpr = [0.45, 0.60, 0.68, 0.97]

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, marker='o', label='Case Study Models')
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='Random Guess')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Curve from Case Study Table')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
import matplotlib.pyplot as plt

u = np.array([1, 0])
v = np.array([0, 1])
z = u - v

# 画图
plt.quiver(0, 0, u[0], u[1], angles='xy', scale_units='xy', scale=1, color='r', label='u')
plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='b', label='v')
plt.quiver(0, 0, z[0], z[1], angles='xy', scale_units='xy', scale=1, color='g', label='u-v')

plt.xlim(-1, 2)
plt.ylim(-2, 2)
plt.grid()
plt.legend(['u', 'v', 'u-v'])
plt.show()
